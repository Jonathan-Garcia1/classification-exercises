# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size: 20px;">
#
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
#
# <div style='background-color: #F5F5F5; padding: 20px; color: Green; font-size: 18px;'>

# %% [markdown]
# <div class="alert alert-block alert-success" style="font-size: 20px;">
#
# Methodologies I > Classification > Data Acquisition

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size: 20px;">
#
# In a jupyter notebook, classification_exercises.ipynb, use a python module (pydata or seaborn datasets) containing datasets as a source from the iris data. Create a pandas dataframe, df_iris, from this data.

# %%
import seaborn as sns
import pandas as pd
import os
import acquire

# %%
# Load the iris dataset
iris = sns.load_dataset("iris")

# %% [markdown]
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
# Print the first 3 rows

# %%
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
# print the number of rows and columns (shape)

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
# print the column names

# %%
iris[:0]
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species]
# Index: []

# %% [markdown]
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
# print the data type of each column

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
# print the summary statistics for each of the numeric variables

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size: 20px;">
# 5 Read the data from this google sheet into a dataframe, df_google.

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'    

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df_googlesheet = pd.read_csv(csv_export_url)

# %% [markdown]
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
# print the first 3 rows

# %%
df_googlesheet.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
# print the number of rows and columns

# %%
df_googlesheet.shape
# Out:
# (891, 12)

# %% [markdown]
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
# print the column names

# %%
#adams code to lower case all the columsn #sidetrack
df_googlesheet.columns = [col.lower() for col in df_googlesheet.columns]

# %%
df_googlesheet.columns
# Out:
# Index(['passengerid', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='object')

# %% [markdown]
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
# print the data type of each column

# %%
df_googlesheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerid  891 non-null    int64
#  1   survived     891 non-null    int64
#  2   pclass       891 non-null    int64
#  3   name         891 non-null    object
#  4   sex          891 non-null    object
#  5   age          714 non-null    float64
#  6   sibsp        891 non-null    int64
#  7   parch        891 non-null    int64
#  8   ticket       891 non-null    object
#  9   fare         891 non-null    float64
#  10  cabin        204 non-null    object
#  11  embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
# print the summary statistics for each of the numeric variables

# %%
df_googlesheet.describe()
# Out:
#        passengerid    survived      pclass         age       sibsp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             parch        fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
# print the unique values for each of your categorical variables

# %%
print(f'Survived = {df_googlesheet.survived.unique()}') 
print(f'Sex = {df_googlesheet.sex.unique()}')
print(f'SibSp = {df_googlesheet.sibsp.unique()}')
print(f'Parch = {df_googlesheet.parch.unique()}')
print(f'Embarked = {df_googlesheet.embarked.unique()}')
# Out:
# Survived = [0 1]
# Sex = ['male' 'female']
# SibSp = [1 0 3 4 2 5 8]
# Parch = [0 1 2 5 3 4 6]
# Embarked = ['S' 'C' 'Q' nan]

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size: 20px;">
# 6 Download the previous exercise's file into an excel (File → Download → Microsoft Excel). Read the downloaded file into a dataframe named df_excel.

# %%
df_excel = pd.read_excel('train.xlsx')
df_excel.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
# assign the first 100 rows to a new dataframe, df_excel_sample
# </div>

# %%
df_excel_sample = df_excel[:100]
df_excel_sample.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
# print the number of rows of your original dataframe

# %%
df_excel.shape[0]
# Out:
# 891

# %% [markdown]
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
# print the first 5 column names

# %%
df_excel.columns[0:5]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex'], dtype='object')

# %% [markdown]
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
# print the column names that have a data type of object

# %%
df_excel.columns[df_excel.dtypes == 'object']
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# <div style='background-color: #F5F5F5; padding: 20px; color: #1A5E7F; font-size: 18px;'>
# compute the range for each of the numeric variables.

# %%
#how to filter the columns to ones with type int64
df_excel_ints = df_excel.columns[df_excel.dtypes == 'int64']

# %%
#use describe function on the fileterd column list
df_excel_info = df_excel[df_excel_ints].describe()
df_excel_info.head()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.523008    0.381594
# std     257.353842    0.486592    0.836071    1.102743    0.806057
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    0.000000    0.000000

# %%
#use only the rows name max and min to calculate the range
df_excel_info.loc['max'] - df_excel_info.loc['min']
# Out:
# PassengerId    890.0
# Survived         1.0
# Pclass           2.0
# SibSp            8.0
# Parch            6.0
# dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size: 20px;">
# Make a function named get_titanic_data that returns the titanic data from the codeup data science database as a pandas data frame. Obtain your data from the Codeup Data Science Database.

# %%
titanic = get_titanic_data()
titanic.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 titanic = get_titanic_data()
#       2 titanic.head()
#
# NameError: name 'get_titanic_data' is not defined

# %% [markdown]
# <div class="alert alert-block alert-success" style="font-size: 20px;">
#
# Methodologies I > Classification > Data Preparation

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size: 20px;">
# 1- Using the Iris Data:

# %% [markdown]
# <div style='background-color: #F5F5F5; padding-left: 40px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px; color: #1A5E7F; font-size: 18px; max-width: 96.65%;'>
# 1- Use the function defined in acquire.py to load the iris data.

# %%
df_iris = acquire.get_iris_data()

# %% [markdown]
# <div style='background-color: #F5F5F5; padding-left: 40px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px; color: #1A5E7F; font-size: 18px; max-width: 96.65%;'>
# 2- Drop the species_id and measurement_id columns.

# %%
df_iris = df_iris.drop(['species_id'], axis= 1)

# %% [markdown]
# <div style='background-color: #F5F5F5; padding-left: 40px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px; color: #1A5E7F; font-size: 18px; max-width: 96.65%;'>
# 3- Rename the species_name column to just species.

# %%
df_iris = df_iris.rename(columns={'species_name': 'species'})
df_iris.head()
# Out:
#   species  sepal_length  sepal_width  petal_length  petal_width
# 0  setosa           5.1          3.5           1.4          0.2
# 1  setosa           4.9          3.0           1.4          0.2
# 2  setosa           4.7          3.2           1.3          0.2
# 3  setosa           4.6          3.1           1.5          0.2
# 4  setosa           5.0          3.6           1.4          0.2

# %% [markdown]
# <div style='background-color: #F5F5F5; padding-left: 40px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px; color: #1A5E7F; font-size: 18px; max-width: 96.65%;'>
# 5- Create a function named prep_iris that accepts the untransformed iris data, and returns the data with the transformations above applied.

# %%
def prep_iris():

    df = acquire.get_iris_data()
    df = df.drop(['species_id'], axis= 1)
    df = df.rename(columns={'species_name': 'species'})
    
    return df

# %%
df_iris = prep_iris()
df_iris.head()
# Out:
#   species  sepal_length  sepal_width  petal_length  petal_width
# 0  setosa           5.1          3.5           1.4          0.2
# 1  setosa           4.9          3.0           1.4          0.2
# 2  setosa           4.7          3.2           1.3          0.2
# 3  setosa           4.6          3.1           1.5          0.2
# 4  setosa           5.0          3.6           1.4          0.2

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size: 20px;">
# 2- Using the Titanic dataset:

# %% [markdown]
# <div style='background-color: #F5F5F5; padding-left: 45px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px; color: #1A5E7F; font-size: 18px; max-width: 96.65%;'>
# 1- Use the function defined in acquire.py to load the Titanic data.

# %%
df_titanic = acquire.get_titanic_data()

# %% [markdown]
# <div style='background-color: #F5F5F5; padding-left: 45px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px; color: #1A5E7F; font-size: 18px; max-width: 96.65%;'>
# 2- Drop any unnecessary, unhelpful, or duplicated columns.

# %%
df_titanic = df_titanic.drop(['passenger_id', 'pclass', 'embarked'], axis= 1)

# %% [markdown]
# <div style='background-color: #F5F5F5; padding-left: 45px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px; color: #1A5E7F; font-size: 18px; max-width: 96.65%;'>
# 4- Create a function named prep_titanic that accepts the raw titanic data, and returns the data with the transformations above applied.

# %%
def prep_titanic():
    df = acquire.get_titanic_data()
    df = df.drop(['passenger_id', 'pclass', 'embarked'], axis= 1)
    return df

# %%
test_titanic = prep_titanic()
test_titanic.head()
# Out:
#    survived     sex   age  sibsp  parch     fare  class deck  embark_town  \
# 0         0    male  22.0      1      0   7.2500  Third  NaN  Southampton
# 1         1  female  38.0      1      0  71.2833  First    C    Cherbourg
# 2         1  female  26.0      0      0   7.9250  Third  NaN  Southampton
# 3         1  female  35.0      1      0  53.1000  First    C  Southampton
# 4         0    male  35.0      0      0   8.0500  Third  NaN  Southampton
#
#    alone
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size: 20px;">
# 3- Using the Telco dataset:

# %% [markdown]
# <div style='background-color: #F5F5F5; padding-left: 40px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px; color: #1A5E7F; font-size: 18px; max-width: 96.65%;'>
# 1- Use the function defined in acquire.py to load the Telco data.

# %%
df_telco = acquire.get_telco_data()

# %%
df_telco.head()
# Out:
#    gender  senior_citizen partner dependents  tenure phone_service  \
# 0  Female               0     Yes        Yes       9           Yes
# 1    Male               0      No         No       9           Yes
# 2    Male               0      No         No       4           Yes
# 3    Male               1     Yes         No      13           Yes
# 4  Female               1     Yes         No       3           Yes
#
#   multiple_lines online_security online_backup device_protection tech_support  \
# 0             No              No           Yes                No          Yes
# 1            Yes              No            No                No           No
# 2             No              No            No               Yes           No
# 3             No              No           Yes               Yes           No
# 4             No              No            No                No          Yes
#
#   streaming_tv streaming_movies paperless_billing  monthly_charges  \
# ...

# %% [markdown]
# <div style='background-color: #F5F5F5; padding-left: 40px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px; color: #1A5E7F; font-size: 18px; max-width: 96.65%;'>
# 2- Drop any unnecessary, unhelpful, or duplicated columns. This could mean dropping foreign key columns but keeping the corresponding string values, for example.

# %%
df_telco = df_telco.drop(['payment_type_id', 'internet_service_type_id', 'contract_type_id', 'customer_id'], axis= 1)

# %% [markdown]
# <div style='background-color: #F5F5F5; padding-left: 40px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px; color: #1A5E7F; font-size: 18px; max-width: 96.65%;'>
# 4- Create a function named prep_telco that accepts the raw telco data, and returns the data with the transformations above applied.

# %%
def prep_telco():
    df = acquire.get_telco_data()
    df = df.drop(['payment_type_id', 'internet_service_type_id', 'contract_type_id', 'customer_id'], axis= 1)
    return df

# %%
df_telco.head()
# Out:
#    gender  senior_citizen partner dependents  tenure phone_service  \
# 0  Female               0     Yes        Yes       9           Yes
# 1    Male               0      No         No       9           Yes
# 2    Male               0      No         No       4           Yes
# 3    Male               1     Yes         No      13           Yes
# 4  Female               1     Yes         No       3           Yes
#
#   multiple_lines online_security online_backup device_protection tech_support  \
# 0             No              No           Yes                No          Yes
# 1            Yes              No            No                No           No
# 2             No              No            No               Yes           No
# 3             No              No           Yes               Yes           No
# 4             No              No            No                No          Yes
#
#   streaming_tv streaming_movies paperless_billing  monthly_charges  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size: 20px;">
# 4- Split your data:

# %% [markdown]
# <div style='background-color: #F5F5F5; padding-left: 40px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px; color: #1A5E7F; font-size: 18px; max-width: 96.65%;'>
# - Write a function to split your data into train, test and validate datasets. Add this function to prepare.py.

# %%
#import at start
from sklearn.model_selection import train_test_split

# %%
def splitf (df, param_stratify, param_seed):
    seed = param_seed

    train, val_test = train_test_split(df, train_size = 0.7,
                                    random_state = seed,
                                    stratify = df[param_stratify])

    val, test = train_test_split(val_test, train_size = 0.5,
                                random_state = seed,
                                stratify = val_test[param_stratify])
    return train, val, test

# %% [markdown]
# <div style='background-color: #F5F5F5; padding-left: 40px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px; color: #1A5E7F; font-size: 18px; max-width: 96.65%;'>
# - Run the function in your notebook on the Iris dataset, returning 3 datasets, train_iris, validate_iris and test_iris.

# %%
df_train, df_val, df_test = splitf(df_iris, 'species', 42 )

# %%
df_train.head()
# Out:
#         species  sepal_length  sepal_width  petal_length  petal_width
# 98   versicolor           5.1          2.5           3.0          1.1
# 68   versicolor           6.2          2.2           4.5          1.5
# 19       setosa           5.1          3.8           1.5          0.3
# 143   virginica           6.8          3.2           5.9          2.3
# 99   versicolor           5.7          2.8           4.1          1.3

# %%
df_val.head()
# Out:
#         species  sepal_length  sepal_width  petal_length  petal_width
# 77   versicolor           6.7          3.0           5.0          1.7
# 111   virginica           6.4          2.7           5.3          1.9
# 69   versicolor           5.6          2.5           3.9          1.1
# 133   virginica           6.3          2.8           5.1          1.5
# 141   virginica           6.9          3.1           5.1          2.3

# %%
df_test.head()
# Out:
#         species  sepal_length  sepal_width  petal_length  petal_width
# 18       setosa           5.7          3.8           1.7          0.3
# 38       setosa           4.4          3.0           1.3          0.2
# 134   virginica           6.1          2.6           5.6          1.4
# 57   versicolor           4.9          2.4           3.3          1.0
# 127   virginica           6.1          3.0           4.9          1.8

# %% [markdown]
# <div style='background-color: #F5F5F5; padding-left: 40px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px; color: #1A5E7F; font-size: 18px; max-width: 96.65%;'>
# - Run the function on the Titanic dataset, returning 3 datasets, train_titanic, validate_titanic and test_titanic.

# %%
train_titanic, val_titanic, test_titanic = splitf(df_titanic, 'survived', 42 )

# %%
train_titanic.head()
# Out:
#      survived     sex   age  sibsp  parch     fare  class deck  embark_town  \
# 748         0    male  19.0      1      0  53.1000  First    D  Southampton
# 45          0    male   NaN      0      0   8.0500  Third  NaN  Southampton
# 28          1  female   NaN      0      0   7.8792  Third  NaN   Queenstown
# 633         0    male   NaN      0      0   0.0000  First  NaN  Southampton
# 403         0    male  28.0      1      0  15.8500  Third  NaN  Southampton
#
#      alone
# 748      0
# 45       1
# 28       1
# 633      1
# 403      0

# %%
val_titanic.head()
# Out:
#      survived   sex   age  sibsp  parch     fare   class deck  embark_town  \
# 377         0  male  27.0      0      2  211.500   First    C    Cherbourg
# 244         0  male  30.0      0      0    7.225   Third  NaN    Cherbourg
# 72          0  male  21.0      0      0   73.500  Second  NaN  Southampton
# 815         0  male   NaN      0      0    0.000   First    B  Southampton
# 841         0  male  16.0      0      0   10.500  Second  NaN  Southampton
#
#      alone
# 377      0
# 244      1
# 72       1
# 815      1
# 841      1

# %%
test_titanic.head()
# Out:
#      survived     sex   age  sibsp  parch     fare   class deck  embark_town  \
# 455         1    male  29.0      0      0   7.8958   Third  NaN    Cherbourg
# 607         1    male  27.0      0      0  30.5000   First  NaN  Southampton
# 142         1  female  24.0      1      0  15.8500   Third  NaN  Southampton
# 883         0    male  28.0      0      0  10.5000  Second  NaN  Southampton
# 835         1  female  39.0      1      1  83.1583   First    E    Cherbourg
#
#      alone
# 455      1
# 607      1
# 142      0
# 883      1
# 835      0

# %% [markdown]
# <div style='background-color: #F5F5F5; padding-left: 40px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px; color: #1A5E7F; font-size: 18px; max-width: 96.65%;'>
# - Run the function on the Telco dataset, returning 3 datasets, train_telco, validate_telco and test_telco.

# %%
train_telco, val_telco, test_telco = splitf(df_telco, 'internet_service_type', 42 )

# %%
train_telco.head()
# Out:
#       gender  senior_citizen partner dependents  tenure phone_service  \
# 4151    Male               1     Yes         No       6           Yes
# 221   Female               0      No         No      41           Yes
# 4562    Male               0     Yes         No       5           Yes
# 3730  Female               0     Yes         No      52            No
# 5629    Male               0     Yes         No      70           Yes
#
#         multiple_lines online_security online_backup device_protection  \
# 4151                No              No           Yes                No
# 221                Yes              No           Yes               Yes
# 4562               Yes              No           Yes                No
# 3730  No phone service             Yes            No               Yes
# 5629               Yes             Yes           Yes               Yes
#
#      tech_support streaming_tv streaming_movies paperless_billing  \
# ...

# %%
val_telco.head()
# Out:
#       gender  senior_citizen partner dependents  tenure phone_service  \
# 1169    Male               1      No         No       5           Yes
# 2614    Male               1      No         No      24           Yes
# 3961    Male               0      No         No      63           Yes
# 6828  Female               0     Yes        Yes      10           Yes
# 6768    Male               0      No         No      67            No
#
#         multiple_lines online_security online_backup device_protection  \
# 1169                No              No            No                No
# 2614               Yes              No           Yes                No
# 3961                No             Yes           Yes               Yes
# 6828                No              No           Yes                No
# 6768  No phone service             Yes            No                No
#
#      tech_support streaming_tv streaming_movies paperless_billing  \
# ...

# %%
test_telco.head()
# Out:
#       gender  senior_citizen partner dependents  tenure phone_service  \
# 6939  Female               0      No        Yes       4            No
# 5654    Male               0     Yes        Yes      65           Yes
# 3776  Female               0      No         No      41           Yes
# 2129    Male               0      No         No      13            No
# 1825    Male               0      No         No      65           Yes
#
#         multiple_lines      online_security        online_backup  \
# 6939  No phone service                  Yes                  Yes
# 5654                No  No internet service  No internet service
# 3776               Yes                   No                   No
# 2129  No phone service                   No                   No
# 1825               Yes  No internet service  No internet service
#
#         device_protection         tech_support         streaming_tv  \
# 6939                  Yes                   No                  Yes
# ...
